# %%
# -*- coding: utf-8 -*-
# Analisis Sentimen MBG - Save Model Version (Final Fixed)

import pandas as pd
import warnings
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score
from joblib import dump

warnings.filterwarnings("ignore")

# =========================
# 1. Muat dataset
# =========================
data = pd.read_csv("dc_tweets_mbg_fix.csv")

print("📊 Jumlah data awal:", len(data))

data = data.dropna(subset=['text'])
data = data[data['text'].str.strip() != '']
print("✅ Jumlah data setelah pembersihan:", len(data))

# =========================
# 2. Fitur & Label
# =========================
X_text = data['text']
y = data['Sentimen_Title'].astype(str)

# =========================
# 3. Split Train & Test
# =========================
X_train, X_test, y_train, y_test = train_test_split(
    X_text, y, test_size=0.1, random_state=42, stratify=y
)

# =========================
# 4. TF-IDF awal untuk SMOTE
# =========================
tfidf = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf.fit_transform(X_train)

# =========================
# 5. SMOTE balancing
# =========================
smote = SMOTE(random_state=32)
X_train_res, y_train_res = smote.fit_resample(X_train_tfidf.toarray(), y_train)

# =========================
# 6. Train model SVM
# =========================
model = SVC(kernel="linear", probability=True, random_state=42)
model.fit(X_train_res, y_train_res)

# =========================
# 7. Evaluasi
# =========================
X_test_tfidf = tfidf.transform(X_test)
y_pred = model.predict(X_test_tfidf)

print("\n=== Classification Report ===")
print(classification_report(y_test, y_pred))

print(f"🎯 Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# =========================
# 8. Final pipeline (TF-IDF + SVM)
# =========================
pipeline = Pipeline([
    ("tfidf", tfidf),
    ("svm", model)
])

# =========================
# 9. Save Model
# =========================
dump(pipeline, "svm_mbg_sentiment.pkl")
print("\n💾 Model berhasil disimpan sebagai svm_mbg_sentiment.pkl")
# Out:
# 📊 Jumlah data awal: 4899
# ✅ Jumlah data setelah pembersihan: 4885
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 64
#      60 # =========================
#      61 # 6. Evaluasi
#      62 # =========================
#      63 X_test_tfidf = pipeline.named_steps["tfidf"].transform(X_test)
# ---> 64 y_pred = pipeline.named_steps["svm"].predict(X_test_tfidf)
#      66 print("\n=== Classification Report ===")
#      67 print(classification_report(y_test, y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:822, in BaseSVC.predict(self, X)
#     820     y = np.argmax(self.decision_function(X), axis=1)
#     821 else:
# --> 822     y = super().predict(X)
#     823 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:436, in BaseLibSVM.predict(self, X)
#     420 def predict(self, X):
#     421     """Perform regression on samples in X.
#     422
#     423     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     434         The predicted values.
#     435     """
# --> 436     X = self._validate_for_predict(X)
#     437     predict = self._sparse_predict if self._sparse else self._dense_predict
#     438     return predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:630, in BaseLibSVM._validate_for_predict(self, X)
#     627     X.sort_indices()
#     629 if sp.issparse(X) and not self._sparse and not callable(self.kernel):
# --> 630     raise ValueError(
#     631         "cannot use sparse input in %r trained on dense data"
#     632         % type(self).__name__
#     633     )
#     635 if self.kernel == "precomputed":
#     636     if X.shape[1] != self.shape_fit_[0]:
#
# ValueError: cannot use sparse input in 'SVC' trained on dense data
